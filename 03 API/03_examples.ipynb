# %% [markdown]
# # Psychoinformatics - Week 3 (Examples)
# by Tsung-Ren (Tren) Huang (trhuang@g.ntu.edu.tw)

# %% [markdown]
# ## 0 Package Installation

# %%
# !pip install dcard-spider facebook-sdk tweepy
# !pip install oauth2 google-api-python-client
# !pip install --upgrade oauth2client

# %% [markdown]
# ## 1 Dcard

# %%
import urllib.request,json
u='https://www.dcard.tw/_api/posts/226048661'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
j_data=json.loads(data.decode('utf-8'))
print(j_data['media'][0]['url'])
for key in j_data.keys():
  print(key,':',j_data[key])
# Out:
# https://i.imgur.com/lof9lya.jpg
# id : 226048661
# title : 套房隔音太差，常常聽到鄰居的...
# content : 我租的套房雖然是水泥隔間
# 但因為屋頂是輕鋼架所以隔音還是不太好
# 沒聽過隔壁貓叫春
# 只有一個不知道是隔壁還是樓下的女人很愛半夜唱歌
#
# 某天被她吵得不行
# 一怒之下把wifi熱點的名字改成
#
# https://i.imgur.com/lof9lya.jpg
#
#
#
# 但我晚上其實不一定在家
# 所以後來也忘了這件事
# 名字也沒改回來
#
# 昨天晚上打電動打到一半wifi突然跳出來
# 看到這個名字我當場笑噴
#
# https://i.imgur.com/GQULLhd.jpg
#
# 看來不只我一個人崩潰啊哈哈哈
# 這位鄰居我好想認識你喔～
# excerpt : 我租的套房雖然是水泥隔間，但因為屋頂是輕鋼架所以隔音還是不太好，沒聽過隔壁貓叫春，只有一個不知道是隔壁還是樓下的女人很愛半夜唱歌，某天被她吵得不行，一怒之下把wifi熱點的名字改成，但我晚上其實不一定在家
# anonymousSchool : False
# anonymousDepartment : False
# pinned : False
# forumId : a1aaa6e6-2594-4968-b7dc-e1b14bea96f4
# replyId : None
# createdAt : 2017-03-25T04:32:58.141Z
# updatedAt : 2018-07-26T00:19:20.397Z
# commentCount : 384
# likeCount : 44027
# tags : ['水泥', '一怒之下', '叫春', '跳出來', '熱點', '打電動', '聽過', '隔音', '鋼架', '隔壁', '名字', '套房', '不一定', '改回來', '屋頂', '吵得', 'wifi', '隔間', '...', '是輕', '件事']
# topics : []
# supportedReactions : None
# withNickname : False
# reportReason :
# hiddenByAuthor : False
# meta : {}
# forumName : 有趣
# forumAlias : funny
# school : 國立臺北大學
# department : 社會工作學系
# replyTitle : None
# gender : F
# personaSubscriptable : True
# reactions : [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 44025}, {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}]
# hidden : False
# customStyle : None
# isSuspiciousAccount : False
# layout : classic
# withImages : True
# withVideos : False
# media : [{'url': 'https://i.imgur.com/lof9lya.jpg'}, {'url': 'https://i.imgur.com/GQULLhd.jpg'}]
# reportReasonText :
# mediaMeta : []
# postAvatar :

# %%
from dcard import Dcard
def filter(metas):
 #return [m for m in metas if m['likeCount'] >= 100]
 return [m for m in metas if "女友" in m['topics']]

d=Dcard()
f=d.forums('photography') #攝影版
m=f.get_metas(num=500,callback=filter) #list
p=d.posts(m).get(comments=False)
r=p.parse_resources() #list: try r[0][1]
done,fails=p.download(r)
print('Got %d pics' % done if len(fails)==0 else 'Error!')
# Out:
# Got 5 pics

# %% [markdown]
# ## Facebook

# %%
import json
def show(j_in):
  print(json.dumps(j_in,ensure_ascii=False,indent=2))

import facebook
token='...'  # replaced by your access token
graph=facebook.GraphAPI(token)
show(graph.get_object('me',fields='id,name,email'))
show(graph.get_connections('me','friends'))
graph.put_object('me','feed',message='Hello from class!')
# see https://stackoverflow.com/questions/52353828/posting-to-facebook-with-python-and-graph-api-permissions-issue
# Out:
# {
#   "id": "10158570278459750",
#   "name": "Tren Huang",
#   "email": "tren.huang@gmail.com"
# }
# {
#   "data": [],
#   "summary": {
#     "total_count": 743
#   }
# }
# ---------------------------------------------------------------------------
# GraphAPIError                             Traceback (most recent call last)
# <ipython-input-46-7e36245c2702> in <module>
#       8 show(graph.get_object('me',fields='id,name,email'))
#       9 show(graph.get_connections('me','friends'))
# ---> 10 graph.put_object('me','feed',message='Hello from class!')
#
# C:\ProgramData\Anaconda3\lib\site-packages\facebook\__init__.py in put_object(self, parent_object, connection_name, **data)
#     190             "{0}/{1}/{2}".format(self.version, parent_object, connection_name),
#     191             post_args=data,
# --> 192             method="POST",
#     193         )
#     194
#
# C:\ProgramData\Anaconda3\lib\site-packages\facebook\__init__.py in request(self, path, args, post_args, files, method)
#     311
#     312         if result and isinstance(result, dict) and result.get("error"):
# --> 313             raise GraphAPIError(result)
#     314         return result
#     315
#
# GraphAPIError: (#200) If posting to a group, requires app being installed in the group, and \
#           either publish_to_groups permission with user token, or both manage_pages \
#           and publish_pages permission with page token; If posting to a page, \
#           requires both manage_pages and publish_pages as an admin with \
#           sufficient administrative permission

# %% [markdown]
# ## Twitter

# %%
import tweepy
key1='HDTBqZDAOuZJyDhsr5Z5tw' # API key 
secret1='nKULl80bwwedY4jtk4UTt2dXotoIVOlPQ8fUVK2LDo' # API secret
key2='206228745-rPUeOG5ZP6Wi3nV5Zd4bwYLRkxthdHVMuidsAbRn' # Access token  
secret2='XcPdcCDXu54FpaYD58KrBQTkCJwsQOdiFpQCbOLh2D09N' # Token secret
auth=tweepy.OAuthHandler(key1,secret1)
auth.set_access_token(key2,secret2)
api=tweepy.API(auth)
data=api.search(q=u'台湾',geocode='22.9500,120.2000,500km')
for tweet in data:
  print(tweet.user.screen_name,tweet.text,'\n')
# Out:
# Cloudliu311 ㊗️台湾ver.レジェンドクエスト(4th)
# 殘🌟132クリア記念！
# 💙🎉㊗️✌️🐱✌️🍾🎊💙
# (2負:レベル47と48..._(:”3」z)_...(完勝殘念です https://t.co/Jasp65NSjI
#
# Sys99527872 RT @MsShuYu: 台湾口罩禁运大陆却供美国，伤透了粉红们的心，实在干得好。想想汶川地震的时候，港台官方民间捐了多少多少亿的钱，一转眼，香港人只不过要中共履行承诺还给香港人普选权，结果被骂成废青暴徒，丢块骨头给狗狗都会朝你摇尾巴，喂白眼狼反遭咬。你处处打压导弹瞄准，还妄想…
#
# 321Brownbear RT @ayanohk: 大好きな台湾🇹🇼
# 感染者が続々と出てきている日本人を受け入れる日は一体いつになるのでしょうか。
#
# 本当に早くおさまることを願うばかりです。
#
# #台湾
#
# konicaamee @sharenewsjapan1 @echigoyadensuke 私は台湾の人々です，
#
# 日本人の高度な知的理解に感謝します。
#
# 日本人の合理的な国籍も賞賛します！ https://t.co/mMszQSNJDI
#
# HrSk115 RT @FunFull_TW: 【お知らせ】
#
# この度、昨日１８日に発令された台湾政府の出入国規制により、
# ４月１８日に開催を予定しておりました
# 「PUMP UP IDOL」の開催を延期が決定いたしました。
#
# ライブを楽しみにして頂いた皆様には心よりお詫び申し上げます。
#
# 振り…
#
# Upgradeby RT @Today__China: 3月19日。
# 今天，台湾海峡发生小冲突，台湾开了11枪。 https://t.co/fydgNh2n8q
#
# ShesKDS 台湾に10日いたから、&amp;強制検疫は残りの4日にしてくれと交渉したらしいけど、ダメだったそうです。
#
# 香港政府から送られてくるはずの監視用アプリが送られてこず、違反者とみなされないかハラハラしているもよう。
#
# 日本領事館からのメールに連絡先が載っていたので送っておきました。
#
# ShesKDS 義母手術の為、直接香港から台湾へ入国できず(台湾で14日間の検疫がある)日本の私の実家で14日間過ごしたあと台湾へ入国した夫。
# 無事強制検疫もなく台湾で10日ほど過ごし、香港へ帰ったら、日本滞在歴があるということで、香港で14日間… https://t.co/cFTXxws3FW
#
# Saitama32002418 RT @Today__China: 3月19日。
# 今天，台湾海峡发生小冲突，台湾开了11枪。 https://t.co/fydgNh2n8q
#
# stickywind RT @Today__China: 3月19日。
# 今天，台湾海峡发生小冲突，台湾开了11枪。 https://t.co/fydgNh2n8q
#
# hwjlovejbl @QXGjdpYYVnHrc2f 台湾和香港是美国和英国领土，何来独立一说
#
# papayamilksan 台湾よりおはようございます！
#
# #今日の積み上げ
#
# ・ブログ2
# ・インスタ2
# ・動画
# ・北原さん
# ・中国語
#
# 子どもが体調を崩してしまいました💦
# できる分だけやります
#
# greeenery_me RT @ukon3333: 台湾　壁面
# taiwan Wall https://t.co/eyT0sqS9xB
#
# Wshuao RT @Today__China: 3月19日。
# 今天，台湾海峡发生小冲突，台湾开了11枪。 https://t.co/fydgNh2n8q
#
# MsShuYu 台湾口罩禁运大陆却供美国，伤透了粉红们的心，实在干得好。想想汶川地震的时候，港台官方民间捐了多少多少亿的钱，一转眼，香港人只不过要中共履行承诺还给香港人普选权，结果被骂成废青暴徒，丢块骨头给狗狗都会朝你摇尾巴，喂白眼狼反遭咬。你处… https://t.co/pfO88AqXKm

# %%
for follower in api.followers_ids('iingwen'):
  user=api.get_user(follower)
  print(user.screen_name,'\t',user.name)
# Out:
# myfriendman 	 Liberate Hong Kong
# zixiang98 	 Z
# joy7312hkk 	 Joy7312hkk
# 5solas2 	 5solas
# Derek86200210 	 Derek
# takuya525 	 David Tsai
# adonis9237 	 Adonis9237
# ZhuChao03736535 	 ZhuChao
# ISRAEL10708338 	 ISRAEL
# 8JYo1Qa0xrr1dpt 	 王超
# HALEY60262796 	 HALEY
# JackyFang1988 	 Jacky Fang
# vc1219 	 Vicky C.
# drV9Md13EVf5moh 	 天佑中華
# Benjami26916424 	 Benjamin Reyes
# Jessica40085740 	 Jessica
# AmandaC87006820 	 Amanda Chen
# taTy96113pOn 	 鵬
# meishi181 	 めいし
# staysafehealthy 	 staysafeandhealthy
# Jessie13381 	 Jessie1338
# mediasonic 	 Mediasonic
# VetClinPath 	 Vet Clin Path Resident
# HelpTaiwan 	 Taiwan Can Help In Italy
# cathy9609 	 Cathy9609
# yaohuiji 	 Yao
# l31725193 	 丁宇
# flora9748 	 Flora9748
# zhang09126063 	 zhang
# Kanwal86860085 	 Kanwal
# Bill90052 	 Bill9005
# e8book 	 bookser
# duncan7207 	 Duncan7207
# Victoria90903 	 Victoria9090
# g7nrNqAAjVfX0rT 	 要信義
# bubucola520 	 esther huang
# GNkRS67YK2NB4HN 	 沐晨
# laurenrachel04 	 Lauren🇨🇦
# x9WVwLaMuuCDg6M 	 刘星
# Tinct_Xu 	 徐成翔Chen_Xu
# hbaitao1 	 Hbaitao
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-74abcdf4e34f> in <module>
#       1 for follower in api.followers_ids('iingwen'):
# ----> 2   user=api.get_user(follower)
#       3   print(user.screen_name,'\t',user.name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     358             ca_cert_dir=self.ca_cert_dir,
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#     362
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     334     if ca_certs or ca_cert_dir:
#     335         try:
# --> 336             context.load_verify_locations(ca_certs, ca_cert_dir)
#     337         except IOError as e:  # Platform-specific: Python 2.7
#     338             raise SSLError(e)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in load_verify_locations(self, cafile, capath, cadata)
#     451         if capath is not None:
#     452             capath = capath.encode("utf-8")
# --> 453         self._ctx.load_verify_locations(cafile, capath)
#     454         if cadata is not None:
#     455             self._ctx.load_verify_locations(BytesIO(cadata))
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in load_verify_locations(self, cafile, capath)
#     787
#     788         load_result = _lib.SSL_CTX_load_verify_locations(
# --> 789             self._context, cafile, capath
#     790         )
#     791         if not load_result:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Google

# %%
DEVELOPER_KEY = "AIzaSyA9h6IVrxz5zStaCWz9aoeZ9FIX_Uq8NZ0"

# %%
from apiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=DEVELOPER_KEY)
result = youtube.videos().list(
    part='snippet,contentDetails,statistics',
    chart='mostPopular',
    regionCode='TW',maxResults=50).execute()
print(result)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag
ch?v=UZHGEyCYgTc\n\n蘇美王表，一塊石頭揭秘人類誕生的真相\nhttps://www.youtube.com/watch?v=Mw-bAl2Tlm0\n\n科學證明進化論才是都市傳說，人類才是外星人 \nhttps://www.youtube.com/watch?v=BFEakK2FA3s\n\n最接近神的男人，特斯拉\nhttps://www.youtube.com/watch?v=2QlzgZPxg1c\n\n二十世紀最大謎團，通古斯大爆炸\nhttps://www.youtube.com/watch?v=wU-GxHtCGgA\n\n波羅的海下的巨大圓盤，它在這裡14萬年了\nhttps://www.youtube.com/watch?v=QAbx4ruDEm0\n\n曼德拉效應，是誰動了我的記憶\nhttps://www.youtube.com/watch?v=5x9mNMnG9lY\n\n谷歌的時間機器和三個時間旅行者\nhttps://www.youtube.com/watch?v=yDO7oZLpXL0\n------------------------------------------------\n推薦播放列表：\n\n【未來】https://goo.gl/Bq54h5\n\n【傳說】https://goo.gl/CpmK2Y\n\n【心理測試】https://goo.gl/wf5dp5\n\n【奇趣】https://goo.gl/Tbpiuj', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wGaTEf0e67U/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/wGaTEf0e67U/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/wGaTEf0e67U/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/wGaTEf0e67U/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/wGaTEf0e67U/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': '老高與小茉 Mr & Mrs Gao', 'tags': ['巧合', '榮格', '集體潛意識', '預言', '易經'], 'categoryId': '24', 'liveBroadcastContent': 'none', 'defaultLanguage': 'en', 'localized': {'title': '【震撼】一切都不是巧合，2020真正的預言 | 老高與小茉 Mr & Mrs Gao', 'description': '【加入會員按鈕】https://www.youtube.com/channel/UCMUnInmOkrWN4gof9KlhNmQ/join\n【出賣靈魂按鈕】https://goo.gl/VhzZeS\n------------------------------------------------\n相關鏈接：\n\n【震撼】2045年，人類究竟是滅絕還是成神\nhttps://www.youtube.com/watch?v=WY4XLDBDyuk\n\n出賣靈魂的正確方法，魔鬼聖經\nhttps://www.youtube.com/watch?v=0vomd4ymSLc\n\n【一個人不要看】至少需要4個人一起看的影片\nhttps://www.youtube.com/watch?v=nAc6sGXLueY\n\n【震撼】地球歷史的最大謎團，大洪水\nhttps://www.youtube.com/watch?v=w69h0zCso-o\n\n人類不能知道的秘密，人族的故事\nhttps://www.youtube.com/watch?v=JVOzntXOGRc\n\n地球監獄說，其實人類的祖先是星際囚犯，咱們都在地球上改造\nhttps://www.youtube.com/watch?v=-WhhhLTH1yk\n\n中國古代全都是外星人， ...

# %%
def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

    youtube = build('youtube','v3',developerKey=DEVELOPER_KEY)

    search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=max_results,
    location=location,
    locationRadius=location_radius).execute()

    title = []
    channelId = []
    channelTitle = []
    categoryId = []
    videoId = []
    viewCount = []
    likeCount = []
    dislikeCount = []
    commentCount = []
    favoriteCount = []
    category = []
    tags = []
    videos = []
    
    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":

            title.append(search_result['snippet']['title']) 

            videoId.append(search_result['id']['videoId'])

            response = youtube.videos().list(
                part='statistics, snippet',
                id=search_result['id']['videoId']).execute()

            channelId.append(response['items'][0]['snippet']['channelId'])
            channelTitle.append(response['items'][0]['snippet']['channelTitle'])
            categoryId.append(response['items'][0]['snippet']['categoryId'])
            favoriteCount.append(response['items'][0]['statistics']['favoriteCount'])
            viewCount.append(response['items'][0]['statistics']['viewCount'])
            likeCount.append(response['items'][0]['statistics']['likeCount'])
            dislikeCount.append(response['items'][0]['statistics']['dislikeCount'])
 
        if 'commentCount' in response['items'][0]['statistics'].keys():
            commentCount.append(response['items'][0]['statistics']['commentCount'])
        else:
            commentCount.append([])
        if 'tags' in response['items'][0]['snippet'].keys():
            tags.append(response['items'][0]['snippet']['tags'])
        else:
            tags.append([])

    youtube_dict = {'tags':tags,'channelId': channelId,'channelTitle': channelTitle,'categoryId':categoryId,'title':title,'videoId':videoId,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount,'favoriteCount':favoriteCount}

    return youtube_dict

# %%
import pandas as pd
test = youtube_search("韓國瑜")
df = pd.DataFrame(data=test)
df
# Out:
#                                                  tags  \
# 0                        [年代, 年代新聞, 政論節目, 新聞面對面, 謝震武]
# 1         [TVBS, TVBS新聞台, 獨家, 新聞, 全球新聞, 時事, 專題, NEWS]
# 2   [東森, 東森新聞, EBC, 新聞, news, ETTV, Ch51, 台灣, ㄉㄨㄥ森...
# 3                        [年代, 年代新聞, 政論節目, 新聞面對面, 謝震武]
# 4         [TVBS, TVBS新聞台, 獨家, 新聞, 全球新聞, 時事, 專題, NEWS]
# 5                        [自由電子報, 自由影音, 自由時報, 自由時報電子報]
# 6   [中天新聞直播, 中天新聞, 新聞, 政治, 娛樂, 生活, 消費, 國際, 兩岸, 社會,...
# 7         [TVBS, TVBS新聞台, 獨家, 新聞, 全球新聞, 時事, 專題, NEWS]
# 8           [东南卫视, 海峡新干线, 台海, 新闻, 时政, 社会, 政治, 海峡, 热点]
# 9   [中天新聞直播, 中天新聞, 新聞, 政治, 娛樂, 生活, 消費, 國際, 兩岸, 社會,...
# 10  [東森, 東森新聞, EBC, 新聞, news, ETTV, Ch51, 台灣, ㄉㄨㄥ森...
# 11  [韓國瑜, 李四端, 大雲時堂, 大雲文創, 高雄市長, 廖達奇, 廖達琪, 陳鳳興, 選舉...
# 12                [民視, 民視新聞, FTV, FTVN, FTV News, 政治]
# 13                                                 []
# 14          [东南卫视, 海峡新干线, 台海, 新闻, 时政, 社会, 政治, 海峡, 热点]
# 15        [TVBS, TVBS新聞台, 獨家, 新聞, 全球新聞, 時事, 專題, NEWS]
# 16  [東森, 東森新聞, EBC, 新聞, news, ETTV, Ch51, 台灣, ㄉㄨㄥ森...
# 17                [民視, 民視新聞, FTV, FTVN, FTV News, 政治]
# 48        [TVBS, TVBS新聞台, 獨家, 新聞, 全球新聞, 時事, 專題, NEWS]
# 49  [udn tv, 即時直播, 韓國瑜, 張善政, 選前之夜, 2020總統大選, 高雄夢時代...
#
#                    channelId  \
# 0   UC8w76cjoqEArF-ns44l_ujA
# 1   UC5nwNW4KdC0SzrhF9BXEYOQ
# 2   UCR3asjvr_WAaxwJYEDV_Bfw
# 3   UC8w76cjoqEArF-ns44l_ujA
# 4   UC5nwNW4KdC0SzrhF9BXEYOQ
# 5   UCrbctXCueK60wHFE2o8YL-Q
# 6   UCpu3bemTQwAU8PqM4kJdoEQ
# 7   UC5nwNW4KdC0SzrhF9BXEYOQ
# 8   UCN2e8dLY9KnH-B15LyBM7Fg
# 9   UCpu3bemTQwAU8PqM4kJdoEQ
# 10  UCR3asjvr_WAaxwJYEDV_Bfw
# 11  UCeeZZSeqKz3ZDrO1oxQkxfQ
# 12  UC2VmWn8dAqkzlQqvy02E1PA
# 13  UC5nwNW4KdC0SzrhF9BXEYOQ
# 14  UCN2e8dLY9KnH-B15LyBM7Fg
# 15  UC5nwNW4KdC0SzrhF9BXEYOQ
# 16  UCR3asjvr_WAaxwJYEDV_Bfw
# 17  UC2VmWn8dAqkzlQqvy02E1PA
# 18  UCnAsZ46UTeFEgwOEwMezngQ
# 19  UC5l1Yto5oOIgRXlI4p4VKbw
# 20  UC5l1Yto5oOIgRXlI4p4VKbw
# 21  UCrbctXCueK60wHFE2o8YL-Q
# 22  UC8ROUUjHzEQm-ndb69CX8Ww
# 23  UCoNYj9OFHZn3ACmmeRCPwbA
# 24  UC5nwNW4KdC0SzrhF9BXEYOQ
# 25  UC810IgOuxrW4kjQ9ohIczVg
# 26  UCDCJyLpbfgeVE9iZiEam-Kg
# 27  UC5nwNW4KdC0SzrhF9BXEYOQ
# 28  UC8ROUUjHzEQm-ndb69CX8Ww
# 29  UC2TuODJhC03pLgd6MpWP0iw
# 30  UC8ROUUjHzEQm-ndb69CX8Ww
# 31  UC5l1Yto5oOIgRXlI4p4VKbw
# 32  UC2ATMznIeVwWJUH8Fx4KDWA
# 33  UCrbctXCueK60wHFE2o8YL-Q
# 34  UC5nwNW4KdC0SzrhF9BXEYOQ
# 35  UCLZBXiS9ZrIXgKBs_SMfGBQ
# 36  UC8ROUUjHzEQm-ndb69CX8Ww
# 37  UCmdVfsLHu18lCkKYXSOGUxg
# 38  UCLZBXiS9ZrIXgKBs_SMfGBQ
# 39  UC2M61YK4ntt9iK-23XhDwcw
# 40  UC5l1Yto5oOIgRXlI4p4VKbw
# 41  UC8ROUUjHzEQm-ndb69CX8Ww
# 42  UCN2e8dLY9KnH-B15LyBM7Fg
# 43  UC5nwNW4KdC0SzrhF9BXEYOQ
# 44  UCN2e8dLY9KnH-B15LyBM7Fg
# 45  UCR3asjvr_WAaxwJYEDV_Bfw
# 46  UC5l1Yto5oOIgRXlI4p4VKbw
