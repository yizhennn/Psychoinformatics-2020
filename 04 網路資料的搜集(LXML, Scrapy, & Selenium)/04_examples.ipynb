# %% [markdown]
# # Psychoinformatics - Week 4 (Examples)
# by Tsung-Ren (Tren) Huang (trhuang@g.ntu.edu.tw)

# %% [markdown]
# ## 1 HTML & CSS

# %% [markdown]
# ### 1.1 Getting pages from PTT

# %%
import urllib.request

# %% [markdown]
# #### 1.1.1 List of articles

# %%
u='http://www.ptt.cc/bbs/Boy-Girl/'
    #u是URL的意思，簡寫成u
    
r=urllib.request.Request(u,headers={'User-Agent':''})
    #'User-Agent可以是chrome或是IE firefox這裡是空白：沒有指定我是誰
    
data=urllib.request.urlopen(r).read()
    #用URL open r那一行request
    
print(data.decode('utf-8'))
    #沒有用'utf-8 decode中文會變成亂碼喔
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Boy-Girl 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2172558837/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Boy-Girl/index.html"><span class="board-label">看板 </span>Boy-Girl</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Boy-Girl/index.html">看板</a>
# 				<a class="btn" href="/man/Boy-Girl/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Boy-Girl/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Boy-Girl/index4792.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Boy-Girl/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1586240734.A.995.html">Re: [分享] 為什麼男生喜歡小女生</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">moshenisshit</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E5%88%86%E4%BA%AB%5D&#43;%E7%82%BA%E4%BB%80%E9%BA%BC%E7%94%B7%E7%94%9F%E5%96%9C%E6%AD%A1%E5%B0%8F%E5%A5%B3%E7%94%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3Amoshenisshit">搜尋看板內 moshenisshit 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/07</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1399818891.A.D72.html">[公告] 關於新制板規說明（必讀）</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">snda</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E9%97%9C%E6%96%BC%E6%96%B0%E5%88%B6%E6%9D%BF%E8%A6%8F%E8%AA%AA%E6%98%8E%EF%BC%88%E5%BF%85%E8%AE%80%EF%BC%89">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3Asnda">搜尋看板內 snda 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 5/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1554727003.A.986.html">[公告] 檢舉格式教學</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ChenDao</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E6%AA%A2%E8%88%89%E6%A0%BC%E5%BC%8F%E6%95%99%E5%AD%B8">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3AChenDao">搜尋看板內 ChenDao 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/08</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1560802697.A.8E6.html">[公告] 有關於&#34;問卷文申請&#34;</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ChenDao</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E6%9C%89%E9%97%9C%E6%96%BC%22%E5%95%8F%E5%8D%B7%E6%96%87%E7%94%B3%E8%AB%8B%22">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3AChenDao">搜尋看板內 ChenDao 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 6/18</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1565730811.A.BDC.html">[公告] 男女板板規</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ChenDao</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E7%94%B7%E5%A5%B3%E6%9D%BF%E6%9D%BF%E8%A6%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3AChenDao">搜尋看板內 ChenDao 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/14</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Boy-Girl/M.1560802801.A.AE3.html">[置底閒聊] 18/06/2019 04:17am </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ChenDao</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=thread%3A%5B%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%5D&#43;18%2F06%2F2019&#43;04%3A17am&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Boy-Girl/search?q=author%3AChenDao">搜尋看板內 ChenDao 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 6/18</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script type="text/javascript">(function(){window['__CF$cv$params']={r:'5801e75299beae61',m:'9d6ca4ebcced40638e39dad4b0dba30c45749826-1586243162-1800-AZgB0yMgQnAJ+QCESPVy0ep0SFF7leTkHZaJ4ubXSAZsR/09aLdDC4Ma2Zw0A2Harqzo81xP679dwiOAhP7a5UUswVjqtZ6iBtutmIxS5oMoqSIpLZ5lcp2z4uhQ5Mfor5UPZxzbW50h0En6NvK+uhc=',s:[0x5700780dd6,0xe865472e4f],fb:0,}})();</script></body>
# </html>

# %% [markdown]
# #### 1.1.2 A specific article

# %%
u='https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r).read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="Re: [心情] 我要怎麼原諒那個人">
# <meta property="og:description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2172558837/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Boy-Girl/index.html"><span class="board-label">看板 </span>Boy-Girl</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/Boy-Girl/index.html">返回看板</a>
# 		<div class="bar"></div>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">wbson (Simple Power)</span></div><div class="article-metaline-right"><span class="article-meta-tag">站內</span><span class="article-meta-value">Boy-Girl</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">Re: [心情] 我要怎麼原諒那個人</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Mar 16 18:00:03 2014</span></div>
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# <span class="f2">※ 引述《Qion (珍惜)》之銘言：
# </span><span class="f6">: 在一個人身上花了八九年的時間
# </span><span class="f6">: 因為既有的問題無法解決 關於結婚也無法達成共識
# </span><span class="f6">: 我們分手了
# </span><span class="f6">: 他不到三個月就交了新的 是以前就常一起出國玩
# </span><span class="f6">: 會去接送的人 為什麼是她。。。
# </span><span class="f6">: 現在聽說要結婚(一年多了)
# </span><span class="f6">: 怎麼辦呢我毫無意識的眼淚掉了滿地
# </span><span class="f6">: 這個爛人
# </span><span class="f6">: 共同的朋友不敢告訴我但還是被我知道了
# </span><span class="f6">: 這個人我無法原諒
# </span><span class="f6">: 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# </span><span class="f6">: 好想選擇一個容易的 逃避一切痛苦的方法
# </span><span class="f6">: 可是我能嗎?
# </span><span class="f6">: 我這麼努力的 好好活著 重新建立我的生活
# </span><span class="f6">: 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# </span><span class="f6">: 可是我的堅強還是被打垮
# </span><span class="f6">: 真的很恨他 如果可以不遇見 該有多好
# </span>
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span>◆ From: 172.2.206.224
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">winds19903</span><span class="f3 push-content">:推最後一段</span><span class="push-ipdatetime"> 03/16 19:25
# </span></div></div>
#
#     <div id="article-polling" data-pollurl="/poll/Boy-Girl/M.1394964006.A.850.html?cacheKey=2084-98589289&amp;offset=1501&amp;offset-sig=524863f83251ebdca4f0be5e2b26cbe7059a9c99" data-longpollurl="/v1/longpoll?id=76cff78a4ab7fe3c25ed6ed834e5f07b4ccd1909" data-offset="1501"></div>
#
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script type="text/javascript">(function(){window['__CF$cv$params']={r:'579f8530eaddfbdc',m:'a6e4812047e618e9b799f8718cf50a56d5479a5d-1585211538-1800-Af5w2fIGLIdXCWkyqzbodiyYrRpQ1S9TO1GSg49bhddAeehdMRhPT9pzkryupVxDpTk+YOKLbfbpVXc4ym+lxlxDaLRN5vNE/rqrWVyGwqWr/YWYc10Mf2TEmTxAKJGryMrQZIDxH2IGLX1Ra5BepE0BEfjhTDWIf/JUFs0EqGdN',s:[0xd8c7a2b329,0x00623cb2fe],fb:0,}})();</script></body>
# </html>

# %%
u='https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html'
r=urllib.request.Request(u,headers={'User-Agent':''})
data=urllib.request.urlopen(r)
print(data.getheaders())
# Out:
# [('Date', 'Thu, 26 Mar 2020 11:04:46 GMT'), ('Content-Type', 'text/html; charset=utf-8'), ('Transfer-Encoding', 'chunked'), ('Connection', 'close'), ('Set-Cookie', '__cfduid=da39d928469c4888c818add9dd1ae61931585220686; expires=Sat, 25-Apr-20 11:04:46 GMT; path=/; domain=.ptt.cc; HttpOnly; SameSite=Lax'), ('Alternate-Protocol', '443:npn-spdy/3'), ('Strict-Transport-Security', 'max-age=0'), ('CF-Cache-Status', 'DYNAMIC'), ('Expect-CT', 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"'), ('Set-Cookie', '__cf_bm=44777e1e3763d9e832eca1ab7b3abfe84ca7f544-1585220686-1800-AWTd4ZgllROYz1INPwFmZDP8SaK2QV+Tqt7AKWjtBNFoqt8O1eMJM97xk0Iizi/2ilr0nm3PYmDcWklzMGqoo3k=; path=/; expires=Thu, 26-Mar-20 11:34:46 GMT; domain=.ptt.cc; HttpOnly; Secure; SameSite=None'), ('X-Content-Type-Options', 'nosniff'), ('Server', 'cloudflare'), ('CF-RAY', '57a06489e945fbd0-KIX')]

# %% [markdown]
# ### 1.2 Basic HTML

# %% [markdown]
# <h1>標1</h1><hr> <h2>標2</hr> <a href="http://ptt.cc">連接</a>
# <br><br><br><br>
# <hr><hr>
# 這樣<br>可以斷行 <img src="http://bit.ly/1p2za46" width=50% />
# <center>這樣可以置中和<font color='red'>換色</font></center>
# <ul>
# <li><b>粗體</b></li>
# <li><i>斜體</i></li>    <li><u>底線</u></li>
# </ul>
# <table border=1>
# <tr><td>11</td>    <td>12</td></tr>
# <tr><td>21</td>                                   <td>22</td></tr>
# </table>

# %% [markdown]
# ### 1.3 Basic CSS

# %% [markdown]
# #### 1.3.1 CSS not working in Jypyter Notebook

# %% [markdown]
# <style>
# body {color:white; background-color:black;}
# h1 {color:red; font-size:20pt}
# .yy {color:yellow}
# span#gg {color:green}
# div#bb {color:blue}
# </style>
# <h1>Hi!</h1>
# This is <span class=yy>test1</span><hr>
# This is <div class=yy>test2</div><hr>
# This is <span id=gg>test3</span><hr>
# This is <div id=gg>test4</div><hr>
# This is <div id=bb>test5</div><hr>

# %% [markdown]
# #### 1.3.2 CSS working in regular webpages

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="http://hpc.psy.ntu.edu.tw/info/04/css.html" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="http://hpc.psy.ntu.edu.tw/info/04/css.html" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# ## 2 Web Crawlers

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downlo
# Collecting PyHamcrest!=1.10.0,>=1.9.0 (from Twisted>=17.9.0->scrapy)
#   Downloading https://files.pythonhosted.org/packages/40/16/e54cc65891f01cb62893540f44ffd3e8dab0a22443e1b438f1a9f5574bee/PyHamcrest-2.0.2-py3-none-any.whl (52kB)
#     100% |████████████████████████████████| 61kB 5.4MB/s ta 0:00:011
# Collecting attrs>=19.2.0 (from Twisted>=17.9.0->scrapy)
#   Downloading https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Requirement already satisfied: pyasn1 in /Users/Apple/anaconda3/lib/python3.7/site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /Users/Apple/anaconda3/lib/python3.7/site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: six>=1.5.2 in /Users/Apple/anaconda3/lib/python3.7/site-packages (from parsel>=1.5.0->scrapy) (1.12.0)
# Requirement already satisfied: setuptools in /Users/Apple/anaconda3/lib/python3.7/site-packages (from zope.interface>=4.1.3->scrapy) (40.6.3)
# Requirement already satisfied: idna>=2.1 in /Users/Apple/anaconda3/lib/python3.7/site-packages (from cryptography>=2.0->scrapy) (2.8)
# Requirement already satisfied: asn1crypto>=0.21.0 in /Users/Apple/anaconda3/lib/python3.7/site-packages (from cryptography>=2.0->scrapy) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in /Users/Apple/anaconda3/lib/python3.7/site-packages (from cryptography>=2.0->scrapy) (1.11.5)
# Requirement already satisfied: pycparser in /Users/Apple/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.7->cryptography>=2.0->scrapy) (2.19)
# Building wheels for collected packages: protego, PyDispatcher
#   Running setup.py bdist_wheel for protego ... done
#   Stored in directory: /Users/Apple/Library/Caches/pip/wheels/51/01/d1/4a2286a976dccd025ba679acacfe37320540df0f2283ecab12
#   Running setup.py bdist_wheel for PyDispatcher ... done
#   Stored in directory: /Users/Apple/Library/Caches/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# Successfully built protego PyDispatcher
# Installing collected packages: incremental, constantly, hyperlink, attrs, Automat, PyHamcrest, zope.interface, Twisted, service-identity, w3lib, cssselect, parsel, protego, queuelib, PyDispatcher, scrapy
#   Found existing installation: attrs 18.2.0
#     Uninstalling attrs-18.2.0:
#       Successfully uninstalled attrs-18.2.0
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 PyHamcrest-2.0.2 Twisted-20.3.0 attrs-19.3.0 constantly-15.1.0 cssselect-1.1.0 hyperlink-19.0.0 incremental-17.5.0 parsel-1.5.2 protego-0.1.16 queuelib-1.5.0 scrapy-2.0.1 service-identity-18.1.0 w3lib-1.21.0 zope.interface-5.0.2

# %% [markdown]
# ### 2.1 LXML & Scrapy
# You can find more about XPath syntax <a href="https://www.w3schools.com/xml/xpath_syntax.asp">here</a>.

# %% [markdown]
# #### 2.1.1 Example 1:
# <p><b>1</b>2<b>3</b></p>

# %%
data='<p><b>1</b>2<b>3</b></p>'

# %% [markdown]
# ##### 2.1.1.1 Using LXML

# %%
import lxml.html
t=lxml.html.fromstring(data)
print(t,t[0],t[1])
print(t.text,t[0].text,t[1].text)
# Out:
# <Element p at 0x10d58d188> <Element b at 0x10d576f48> <Element b at 0x10d58d138>
# None 1 3

# %%
print(t.xpath('//p'))
print(t.xpath('//p')[0].text_content()) #123 #ptt裡面的標題+新文+引言
print(t.xpath('//p')[0].getchildren()) #1,3
print(t.xpath('//b')) #1,3
print(t.xpath('//p/text()')) #2 #ptt裡面的新文
# Out:
# [<Element p at 0x10d58d188>]
# 123
# [<Element b at 0x10d58d0e8>, <Element b at 0x10d58d1d8>]
# [<Element b at 0x10d58d0e8>, <Element b at 0x10d58d1d8>]
# ['2']

# %% [markdown]
# ##### 2.1.1.2 Using Scrapy Selector

# %%
from scrapy.selector import Selector

# %%
t=Selector(text=data)
print(t)
# Out:
# <Selector xpath=None data='<html><body><p><b>1</b>2<b>3</b></p><...'>

# %%
t.xpath('//b').extract()
# Out:
# ['<b>1</b>', '<b>3</b>']

# %%
print(t.xpath('//p').extract())
print(t.xpath('//p/text()').extract())
print(t.xpath('//p/text()').extract_first())
print(t.xpath('//p/*').extract())
print(t.xpath('//p').re('\d'))
# Out:
# ['<p><b>1</b>2<b>3</b></p>']
# ['2']
# 2
# ['<b>1</b>', '<b>3</b>']
# ['1', '2', '3']

# %%
print(t.xpath('//b').extract())
print(t.xpath('//b/text()').extract())
print(t.xpath('//b/text()').extract_first())
# Out:
# ['<b>1</b>', '<b>3</b>']
# ['1', '3']
# 1

# %% [markdown]
# #### 2.1.2 Example 2:
# <table>
# <tr><td>11</td><td>12</td></tr>
# <tr><td>21</td><td><a href="http://ptt.cc">22</a></td></tr>
# <tr><td>31</td><td>32</td></tr>
# </table>

# %%
data='''<table>
<tr><td>11</td><td>12</td></tr>
<tr><td>21</td><td><a href="http://ptt.cc">22</a></td></tr>
<tr><td>31</td><td>32</td></tr>
</table>'''

# %% [markdown]
# ##### 2.1.2.1 Using LXML

# %%
t=lxml.html.fromstring(data)
x=t.xpath('//td')
print(x[0].getparent().getnext().getchildren())
print(t.xpath('//a/@href'))
print(t.xpath('//a/text()'))
# Out:
# [<Element td at 0x1f3eeb764f8>, <Element td at 0x1f3eeb76048>]
# ['http://ptt.cc']
# ['22']

# %% [markdown]
# ##### 2.1.2.1 Using Scrapy Selector

# %%
from scrapy.selector import Selector
t=Selector(text=data)
print(t.xpath('//td'))
print(t.xpath('//td/..')[1].xpath('*/text()'))
# Out:
# [<Selector xpath='//td' data='<td>11</td>'>, <Selector xpath='//td' data='<td>12</td>'>, <Selector xpath='//td' data='<td>21</td>'>, <Selector xpath='//td' data='<td><a href="http://ptt.cc">22</a></td>'>, <Selector xpath='//td' data='<td>31</td>'>, <Selector xpath='//td' data='<td>32</td>'>]
# [<Selector xpath='*/text()' data='21'>]

# %%
print(t.xpath('//a/@href'))
print(t.xpath('//a/@href').extract())
print(t.xpath('//a/text()'))
print(t.xpath('//a/text()').extract())
# Out:
# [<Selector xpath='//a/@href' data='http://ptt.cc'>]
# ['http://ptt.cc']
# [<Selector xpath='//a/text()' data='22'>]
# ['22']

# %% [markdown]
# #### 2.1.3 Collecting links from PTT

html
# 搜尋同標題文章 /bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%94%B7%E5%A5%B3%E6%9D%BF%E6%9D%BF%E8%A6%8F
# 搜尋看板內 ChenDao 的文章 /bbs/Boy-Girl/search?q=author%3AChenDao
# [置底閒聊] 18/06/2019 04:17am  /bbs/Boy-Girl/M.1560802801.A.AE3.html
# 搜尋同標題文章 /bbs/Boy-Girl/search?q=thread%3A%5B%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%5D+18%2F06%2F2019+04%3A17am+
# 搜尋看板內 ChenDao 的文章 /bbs/Boy-Girl/search?q=author%3AChenDao

# %% [markdown]
# ##### 2.1.3.2 Using Scrapy

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class MySpider(scrapy.Spider):
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/"]
    def parse(self, response):
        for link in response.xpath('//a'):
            print(link.xpath('text()').extract())
            print(link.xpath('@href').extract())

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})
process.crawl(MySpider)
process.start()
# Out:
# 2020-03-26 19:28:40 [scrapy.utils.log] INFO: Scrapy 2.0.1 started (bot: scrapybot)
# 2020-03-26 19:28:40 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.19041-SP0
# 2020-03-26 19:28:40 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-03-26 19:28:40 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2020-03-26 19:28:40 [scrapy.extensions.telnet] INFO: Telnet Password: 207f2ef84eb30991
# 2020-03-26 19:28:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-03-26 19:28:41 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-03-26 19:28:41 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-03-26 19:28:41 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-03-26 19:28:41 [scrapy.core.engine] INFO: Spider opened
# 2020-03-26 19:28:41 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-03-26 19:28:41 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-03-26 19:28:41 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.ptt.cc/bbs/Boy-Girl/> from <GET http://www.ptt.cc/bbs/Boy-Girl/>
# 2020-03-26 19:28:41 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Boy-Girl/index.html> from <GET https://www.ptt.cc/bbs/Boy-Girl/>
# 2020-03-26 19:28:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Boy-Girl/index.html> (referer: None)
# 2020-03-26 19:28:42 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-03-26 19:28:42 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1161,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 6339,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 1,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 0.795589,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 3, 26, 11, 28, 42, 238574),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'start_time': datetime.datetime(2020, 3, 26, 11, 28, 41, 442985)}
# 2020-03-26 19:28:42 [scrapy.core.engine] INFO: Spider closed (finished)
# ['批踢踢實業坊']
# ['/bbs/']
# ['Boy-Girl']
# ['/bbs/Boy-Girl/index.html']
# ['關於我們']
# ['/about.html']
# ['聯絡資訊']
# ['/contact.html']
# ['看板']
# ['/bbs/Boy-Girl/index.html']
# ['精華區']
# ['/man/Boy-Girl/index.html']
# ['最舊']
# ['/bbs/Boy-Girl/index1.html']
# ['‹ 上頁']
# ['/bbs/Boy-Girl/index4783.html']
# ['下頁 ›']
# []
# ['最新']
# ['/bbs/Boy-Girl/index.html']
# ['Re: [求助] 在一起沒多久就想分手']
# ['/bbs/Boy-Girl/M.1585198381.A.F5F.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E6%B1%82%E5%8A%A9%5
的文章']
# ['/bbs/Boy-Girl/search?q=author%3Aerc8092']
# ['Re: [討論] 這個影片是不是仇女???']
# ['/bbs/Boy-Girl/M.1585219388.A.9E7.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E9%80%99%E5%80%8B%E5%BD%B1%E7%89%87%E6%98%AF%E4%B8%8D%E6%98%AF%E4%BB%87%E5%A5%B3%3F%3F%3F']
# ['搜尋看板內 sumade 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Asumade']
# ['Re: [討論] 婚後無性生活']
# ['/bbs/Boy-Girl/M.1585219655.A.BDB.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E5%A9%9A%E5%BE%8C%E7%84%A1%E6%80%A7%E7%94%9F%E6%B4%BB']
# ['搜尋看板內 gaba000 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Agaba000']
# ['Re: [討論] 女生最討厭男網友問什麼？']
# ['/bbs/Boy-Girl/M.1585221244.A.B16.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E5%A5%B3%E7%94%9F%E6%9C%80%E8%A8%8E%E5%8E%AD%E7%94%B7%E7%B6%B2%E5%8F%8B%E5%95%8F%E4%BB%80%E9%BA%BC%EF%BC%9F']
# ['搜尋看板內 chocholove 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Achocholove']
# ['[公告] 關於新制板規說明（必讀）']
# ['/bbs/Boy-Girl/M.1399818891.A.D72.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E9%97%9C%E6%96%BC%E6%96%B0%E5%88%B6%E6%9D%BF%E8%A6%8F%E8%AA%AA%E6%98%8E%EF%BC%88%E5%BF%85%E8%AE%80%EF%BC%89']
# ['搜尋看板內 snda 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Asnda']
# ['[公告] 檢舉格式教學']
# ['/bbs/Boy-Girl/M.1554727003.A.986.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%AA%A2%E8%88%89%E6%A0%BC%E5%BC%8F%E6%95%99%E5%AD%B8']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']
# ['[公告] 有關於"問卷文申請"']
# ['/bbs/Boy-Girl/M.1560802697.A.8E6.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9C%89%E9%97%9C%E6%96%BC%22%E5%95%8F%E5%8D%B7%E6%96%87%E7%94%B3%E8%AB%8B%22']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']
# ['[公告] 男女板板規']
# ['/bbs/Boy-Girl/M.1565730811.A.BDC.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%94%B7%E5%A5%B3%E6%9D%BF%E6%9D%BF%E8%A6%8F']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']
# ['[置底閒聊] 18/06/2019 04:17am ']
# ['/bbs/Boy-Girl/M.1560802801.A.AE3.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%5D+18%2F06%2F2019+04%3A17am+']
# ['搜尋看板內 ChenDao 的文章']
# ['/bbs/Boy-Girl/search?q=author%3AChenDao']

# %% [markdown]
# #### 2.1.4 Analyzing texts from PTT

# %% [markdown]
# ##### 2.1.4.1 Using LXML

# %%
import urllib, lxml.html
URL='http://www.ptt.cc'
URN='/bbs/Boy-Girl/M.1394964006.A.850.html'
h={'User-Agent':'Mozilla/5.0'}
r=urllib.request.Request(URL+URN,headers=h)
data=urllib.request.urlopen(r).read()
t=lxml.html.fromstring(data.decode('utf-8'))
print(t.text_content()) #整頁
# Out:
#
#
#
#
#
#
# Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		批踢踢實業坊
# 		›
# 		看板 Boy-Girl
# 		關於我們
# 		聯絡資訊
#
#
#
#
# 		返回看板
#
#
#
#
#     作者wbson (Simple Power)站內Boy-Girl標題Re: [心情] 我要怎麼原諒那個人時間Sun Mar 16 18:00:03 2014
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# ※ 引述《Qion (珍惜)》之銘言：
# : 在一個人身上花了八九年的時間
# : 因為既有的問題無法解決 關於結婚也無法達成共識
# : 我們分手了
# : 他不到三個月就交了新的 是以前就常一起出國玩
# : 會去接送的人 為什麼是她。。。
# : 現在聽說要結婚(一年多了)
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
# : 這個爛人
# : 共同的朋友不敢告訴我但還是被我知道了
# : 這個人我無法原諒
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# : 好想選擇一個容易的 逃避一切痛苦的方法
# : 可是我能嗎?
# : 我這麼努力的 好好活著 重新建立我的生活
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# : 可是我的堅強還是被打垮
# : 真的很恨他 如果可以不遇見 該有多好
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc)
# ◆ From: 172.2.206.224
# 推 winds19903:推最後一段 03/16 19:25
#
#
#
#
#
#
#
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#
#
#
#
#
#
#
#     (function(){window['__CF$cv$params']={r:'580a685d2cb9dacc',m:'3ea194ab21b5c75196fa0c3e14bbea4fd99be4e3-1586332333-1800-Abazxdi64+meENBpkLeo4hTZdc8CCOxiAyAS/25cgf0jRuRbGGGQ9bJWH5jrAses6nIRs4x7i0x7X8FfgnYOUOhsjPCf5MPZ8Cw1CWHlE4wVqRX6qG+08QRDntBRkrMx2dAy1Wlk1z3xnwPrYAEn7qtREql7is6njDXofomZQd3G',s:[0x3de9d35364,0x41462af523],fb:0,}})();

# %%
x=t.xpath('//div[@id="main-content"]')[0]
print(x.text_content()) #主文
# Out:
# 作者wbson (Simple Power)站內Boy-Girl標題Re: [心情] 我要怎麼原諒那個人時間Sun Mar 16 18:00:03 2014
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# ※ 引述《Qion (珍惜)》之銘言：
# : 在一個人身上花了八九年的時間
# : 因為既有的問題無法解決 關於結婚也無法達成共識
# : 我們分手了
# : 他不到三個月就交了新的 是以前就常一起出國玩
# : 會去接送的人 為什麼是她。。。
# : 現在聽說要結婚(一年多了)
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
# : 這個爛人
# : 共同的朋友不敢告訴我但還是被我知道了
# : 這個人我無法原諒
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# : 好想選擇一個容易的 逃避一切痛苦的方法
# : 可是我能嗎?
# : 我這麼努力的 好好活著 重新建立我的生活
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# : 可是我的堅強還是被打垮
# : 真的很恨他 如果可以不遇見 該有多好
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc)
# ◆ From: 172.2.206.224
# 推 winds19903:推最後一段 03/16 19:25

# %%
y=t.xpath('//div[@class="action-bar"]/text()')
print(y) #新文
print(''.join(y))
# Out:
# []

# %%
z=t.xpath('//span[@class="f6"]')
for i in z:
 print(i.text) #引言
# Out:
# : 在一個人身上花了八九年的時間
#
# : 因為既有的問題無法解決 關於結婚也無法達成共識
#
# : 我們分手了
#
# : 他不到三個月就交了新的 是以前就常一起出國玩
#
# : 會去接送的人 為什麼是她。。。
#
# : 現在聽說要結婚(一年多了)
#
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
#
# : 這個爛人
#
# : 共同的朋友不敢告訴我但還是被我知道了
#
# : 這個人我無法原諒
#
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
#
# : 好想選擇一個容易的 逃避一切痛苦的方法
#
# : 可是我能嗎?
#
# : 我這麼努力的 好好活著 重新建立我的生活
#
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
#
# : 可是我的堅強還是被打垮
#
# : 真的很恨他 如果可以不遇見 該有多好

# %%
H=t.xpath('//*[contains(text(),"恨")]')[0]
print(H.text) #含恨
# Out:
# : 真的很恨他 如果可以不遇見 該有多好

# %% [markdown]
# ##### 2.1.4.2 Using Scrapy

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class Spider0(scrapy.Spider): #source
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.text)
        
class Spider1(scrapy.Spider): #body
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(''.join(response.xpath("//body//text()").extract()))
        
class Spider2(scrapy.Spider): #新文
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.xpath('//div[@id="main-content"]/text()').extract()[0].strip())

class Spider3(scrapy.Spider): #引言
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(''.join(response.xpath('//span[@class="f6"]/text()').extract()))
        
class Spider4(scrapy.Spider): #含恨
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.xpath('//*[contains(text(),"恨")]/text()').extract())

# %%
process = CrawlerProcess()
process.crawl(Spider0)
process.start()
# Out:
# 2018-10-10 20:22:58 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 20:22:58 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 20:22:58 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 20:22:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 20:22:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 20:22:59 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 20:22:59 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html> from <GET http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html>
# 2018-10-10 20:22:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html> (referer: None)
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 20:22:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 552,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 4310,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 12, 22, 59, 753312),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 7,
#  'memusage/max': 69537792,
#  'memusage/startup': 69537792,
#  'response_received_count': 1,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2018, 10, 10, 12, 22, 59, 79064)}
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="Re: [心情] 我要怎麼原諒那個人">
# <meta property="og:description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Boy-Girl/index.html"><span class="board-label">看板 </span>Boy-Girl</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/Boy-Girl/index.html">返回看板</a>
# 		<div class="bar"></div>
# 		<div class="share">
# 			<span>分享</span>
# 			<div class="fb-like" data-send="false" data-layout="button_count" data-width="90" data-show-faces="false" data-href="http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"></div>
#
# 			<div class="g-plusone" data-size="medium"></div>
# <script type="text/javascript">
# window.___gcfg = {lang: 'zh-TW'};
# (function() {
# var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# po.src = 'https://apis.google.com/js/plusone.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# })();
# </script>
#
# 		</div>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">wbson (Simple Power)</span></div><div class="article-metaline-right"><span class="article-meta-tag">站內</span><span class="article-meta-value">Boy-Girl</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">Re: [心情] 我要怎麼原諒那個人</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Mar 16 18:00:03 2014</span></div>
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# <span class="f2">※ 引述《Qion (珍惜)》之銘言：
# </span><span class="f6">: 在一個人身上花了八九年的時間
# </span><span class="f6">: 因為既有的問題無法解決 關於結婚也無法達成共識
# </span><span class="f6">: 我們分手了
# </span><span class="f6">: 他不到三個月就交了新的 是以前就常一起出國玩
# </span><span class="f6">: 會去接送的人 為什麼是她。。。
# </span><span class="f6">: 現在聽說要結婚(一年多了)
# </span><span class="f6">: 怎麼辦呢我毫無意識的眼淚掉了滿地
# </span><span class="f6">: 這個爛人
# </span><span class="f6">: 共同的朋友不敢告訴我但還是被我知道了
# </span><span class="f6">: 這個人我無法原諒
# </span><span class="f6">: 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# </span><span class="f6">: 好想選擇一個容易的 逃避一切痛苦的方法
# </span><span class="f6">: 可是我能嗎?
# </span><span class="f6">: 我這麼努力的 好好活著 重新建立我的生活
# </span><span class="f6">: 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# </span><span class="f6">: 可是我的堅強還是被打垮
# </span><span class="f6">: 真的很恨他 如果可以不遇見 該有多好
# </span>
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span>◆ From: 172.2.206.224
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">winds19903</span><span class="f3 push-content">:推最後一段</span><span class="push-ipdatetime"> 03/16 19:25
# </span></div></div>
#
#     <div id="article-polling" data-pollurl="/poll/Boy-Girl/M.1394964006.A.850.html?cacheKey=2100-98589289&amp;offset=1501&amp;offset-sig=524863f83251ebdca4f0be5e2b26cbe7059a9c99" data-longpollurl="/v1/longpoll?id=76cff78a4ab7fe3c25ed6ed834e5f07b4ccd1909" data-offset="1501"></div>
#
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# #### 2.1.4 Sending HTML forms

# %% [markdown]
# ##### 2.1.4.1 Using urllib

# %%
# Not working without sending required info:
import urllib.request 
u='http://www.ptt.cc/bbs/Gossiping/'
h={'User-Agent':'Mozilla/5.0'}
r=urllib.request.Request(u,headers=h)
data=urllib.request.urlopen(r).read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2172558837/api.js'></script></head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script type="text/javascript">(function(){window['__CF$cv$params']={r:'57a10224ac2dfcd5',m:'e3e915539caee224e2cde75d0220c023306b0425-1585227141-1800-ATUX6bHmhvFxzEt0AbuTNUgZ/Qn2FzimRQl+uZxQREc2xELWZ1aTglB0mD1JlXDQsEo8mQ2hZIRz7UN3HwVvqnCJFR88GllYAsGZEC17EyYKHoaMA9km9T8B4jWS7lZqzFfxt08soDD7zWzk0t7cG4dsn1ixJlJXVjkdIj5lpctBS68eoNs8hW08sn3EkE5hVw==',s:[0x57a2a3d3bc,0x831762bf8f],fb:0,}})();</script></body>
# </html>

# %%
# Still not working even with required information:
from urllib import parse,request
URL='https://www.ptt.cc'
URN='/ask/over18'
q=parse.urlencode({'yes':'yes','from':'/bbs/Gossiping/'})
q=q.encode('utf-8')
h={'User-Agent':'Mozilla/5.0'}
req=request.Request(URL+URN,q,h)
response=request.urlopen(req)
data=response.read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %%
# Working version with a cookie set:
from urllib import parse,request
URL='https://www.ptt.cc'
URN='/ask/over18'
q=parse.urlencode({'yes':'yes','from':'/bbs/Gossiping/'})
q=q.encode('utf-8')
h={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'}
req=request.Request(URL+URN,q,h)
response=request.urlopen(req)
data=response.read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2172558837/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39247.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1
from scrapy.http import Request, FormRequest
from scrapy.crawler import CrawlerProcess

class Spider(scrapy.Spider):
    name="ptt"
    
    def start_requests(self):
        yield Request(url='https://www.ptt.cc/ask/over18',cookies={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'},callback=self.login)
        
    def login(self, response):
        yield FormRequest.from_response(
            response,
            formdata={'yes':'yes','from':'/bbs/Gossiping/'},
            callback=self.parse
        )
        
    def parse(self,response):
        print(response.text)
        
        
process = CrawlerProcess()
process.crawl(Spider)
process.start()
# Out:
# 2020-04-08 18:10:08 [scrapy.utils.log] INFO: Scrapy 2.0.1 started (bot: scrapybot)
# 2020-04-08 18:10:08 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.7.1 (default, Dec 14 2018, 13:28:58) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.1.1a  20 Nov 2018), cryptography 2.4.2, Platform Darwin-18.7.0-x86_64-i386-64bit
# 2020-04-08 18:10:08 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-04-08 18:10:08 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-04-08 18:10:08 [scrapy.extensions.telnet] INFO: Telnet Password: 6d097dd26517e7b0
# 2020-04-08 18:10:08 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-04-08 18:10:09 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-04-08 18:10:09 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-04-08 18:10:09 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-04-08 18:10:09 [scrapy.core.engine] INFO: Spider opened
# 2020-04-08 18:10:09 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-04-08 18:10:09 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-04-08 18:10:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/ask/over18> (referer: None)
# 2020-04-08 18:10:09 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/> from <POST https://www.ptt.cc/ask/over18>
# 2020-04-08 18:10:09 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/index.html> from <GET https://www.ptt.cc/bbs/Gossiping/>
# 2020-04-08 18:10:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Gossiping/index.html> (referer: https://www.ptt.cc/ask/over18)
# 2020-04-08 18:10:10 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-04-08 18:10:10 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1863,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 3,
#  'downloader/request_method_count/POST': 1,
#  'downloader/response_bytes': 10201,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 2,
#  'downloader/response_status_count/302': 2,
#  'elapsed_time_seconds': 1.078107,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 4, 8, 10, 10, 10, 137576),
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 10,
#  'memusage/max': 53850112,
#  'memusage/startup': 53850112,
#  'request_depth_max': 1,
#  'response_received_count': 2,
#  'scheduler/dequeued': 4,
#  'scheduler/dequeued/memory': 4,
#  'scheduler/enqueued': 4,
#  'scheduler/enqueued/memory': 4,
#  'start_time': datetime.datetime(2020, 4, 8, 10, 10, 9, 59469)}
# 2020-04-08 18:10:10 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2172558837/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39247.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1586339978.A.F06.html">[問卦] 當年日不落帝-英國 怎麼走到今天這樣？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ronny1020</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%95%B6%E5%B9%B4%E6%97%A5%E4%B8%8D%E8%90%BD%E5%B8%9D-%E8%8B%B1%E5%9C%8B&#43;%E6%80%8E%E9%BA%BC%E8%B5%B0%E5%88%B0%E4%BB%8A%E5%A4%A9%E9%80%99%E6%A8%A3%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aronny1020">搜尋看板內 ronny1020 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/08</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1586340097.A.167.html">[政治] 南鐵東移都計居民敗訴 陳致曉：會上訴</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">johnson20524</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6
div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%84%A1%E5%90%8D%E6%98%AF%E6%80%8E%E9%BA%BC%E8%A2%AB%E5%B9%B9%E6%8E%89%E7%9A%84">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AJulian9x9x9">搜尋看板內 Julian9x9x9 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/08</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1586340542.A.F54.html">Re: [政治] 22年首度平衡預算是「假象」監院：債務1</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Anderson0819</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%94%BF%E6%B2%BB%5D&#43;22%E5%B9%B4%E9%A6%96%E5%BA%A6%E5%B9%B3%E8%A1%A1%E9%A0%90%E7%AE%97%E6%98%AF%E3%80%8C%E5%81%87%E8%B1%A1%E3%80%8D%E7%9B%A3%E9%99%A2%EF%BC%9A%E5%82%B5%E5%8B%991">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AAnderson0819">搜尋看板內 Anderson0819 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/08</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1584722568.A.473.html">[公告] 八卦板板規(2020.03.21)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">DreamYeh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282020.03.21%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ADreamYeh">搜尋看板內 DreamYeh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 3/21</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1585203279.A.721.html">[協尋]  3/25  16點寶山路往食品路車禍影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">funnyemma</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;&#43;3%2F25&#43;&#43;16%E9%BB%9E%E5%AF%B6%E5%B1%B1%E8%B7%AF%E5%BE%80%E9%A3%9F%E5%93%81%E8%B7%AF%E8%BB%8A%E7%A6%8D%E5%BD%B1%E5%83%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Afunnyemma">搜尋看板內 funnyemma 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 3/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">37</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1586058672.A.AC4.html">[協尋] 台南狗狗走失(代PO)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">xxx88550</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;%E5%8F%B0%E5%8D%97%E7%8B%97%E7%8B%97%E8%B5%B0%E5%A4%B1%28%E4%BB%A3PO%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Axxx88550">搜尋看板內 xxx88550 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/05</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1586177914.A.06E.html">[公告] 宣導~~張貼[新聞]請依內建發文格式</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">seabox</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%AE%A3%E5%B0%8E~~%E5%BC%B5%E8%B2%BC%5B%E6%96%B0%E8%81%9E%5D%E8%AB%8B%E4%BE%9D%E5%85%A7%E5%BB%BA%E7%99%BC%E6%96%87%E6%A0%BC%E5%BC%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aseabox">搜尋看板內 seabox 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/06</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">8</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1586326865.A.5D4.html">[公告] 四月份置底閒聊文</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Kay731</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%9B%9B%E6%9C%88%E4%BB%BD%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E6%96%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKay731">搜尋看板內 Kay731 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/08</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script type="text/javascript">(function(){window['__CF$cv$params']={r:'580b326c2d9edac8',m:'d35ef68bc3138ce14ece463fd89a39f97084811b-1586340609-1800-AUTbjzG+1gzyIeKl/+EbtxWTZtkxGnKiMhkyLs+FiO0n3ftZwNdd1yq/M9m3INF6fKb52dYUU8eAfhzjOliV3TEkbrPl7ldSz/EPGj6/vYxBIjGbNVYJJtHf8U2R7YvfFwzrLV+lKKLIwpmefu3p7nQ=',s:[0x364637490a,0xe4efda1a7f],fb:0,}})();</script></body>
# </html>

# %%
import scrapy
from scrapy.http import Request, FormRequest
from scrapy.crawler import CrawlerProcess

class Spider(scrapy.Spider):
    name="ptt"
    
    def start_requests(self):
        yield Request(url='https://www.ptt.cc/ask/over18',cookies={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'},callback=self.login)
        
    def login(self, response):
        yield FormRequest.from_response(
            response,
            formdata={'yes':'yes','from':'/bbs/Gossiping/'},
            callback=self.parse
        )
        
    def parse(self,response):
        print(response.text)
        
        
process = CrawlerProcess()
process.crawl(Spider)
process.start()
# Out:
# 2018-10-10 21:07:10 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 21:07:10 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 21:07:10 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 21:07:10 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 21:07:10 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 21:07:10 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 21:07:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/ask/over18> (referer: None)
# 2018-10-10 21:07:10 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/> from <POST https://www.ptt.cc/ask/over18>
# 2018-10-10 21:07:10 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/index.html> from <GET https://www.ptt.cc/bbs/Gossiping/>
# 2018-10-10 21:07:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Gossiping/index.html> (referer: https://www.ptt.cc/ask/over18)
# 2018-10-10 21:07:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 21:07:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1394,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 3,
#  'downloader/request_method_count/POST': 1,
#  'downloader/response_bytes': 7936,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 2,
#  'downloader/response_status_count/302': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 13, 7, 11, 138992),
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 7,
#  'memusage/max': 69701632,
#  'memusage/startup': 69701632,
#  'request_depth_max': 1,
#  'response_received_count': 2,
#  'scheduler/dequeued': 4,
#  'scheduler/dequeued/memory': 4,
#  'scheduler/enqueued': 4,
#  'scheduler/enqueued/memory': 4,
#  'start_time': datetime.datetime(2018, 10, 10, 13, 7, 10, 290699)}
# 2018-10-10 21:07:11 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39201.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">14</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539176115.A.BC0.html">[問卦] 朋友狗被殺了該怎麼安慰他 </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">KSHLO</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%8B%E5%8F%8B%E7%8B%97%E8%A2%AB%E6%AE%BA%E4%BA%86%E8%A9%B2%E6%80%8E%E9%BA%BC%E5%AE%89%E6%85%B0%E4%BB%96&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKSHLO">搜尋看板內 KSHLO 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539176118.A.F3A.html">Re: [新聞] 挺韓國瑜青年戰舞影片曝光 鄉民看完笑翻</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">DICB</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E6%8C%BA%E9%9F%93%E5%9C%8B%E7%91%9C%E9%9D%92%E5%B9%B4%E6%88%B0%E8%88%9E%E5%BD%B1%E7%89%87%E6%9B%9D%E5%85%89&#43;%E9%84%89%E6%B0%91%E7%9C%8B%E5%AE%8C%E7%AC%91%E7%BF%BB">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ADICB">搜尋看板內 DICB 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539176142.A.7F9.html">[問卦] 排嗡嗡包的有多少是台北市人?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Blacky5566</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%8E%92%E5%97%A1%E5%97%A1%E5%8C%85%E7%9A%84%E6%9C%89%E5%A4%9A%E5%B0%91%E6%98%AF%E5%8F%B0%E5%8C%97%E5%B8%82%E4%BA%BA%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ABlacky5566">搜尋看板內 Blacky5566 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539176156.A.65D.html">[問卦] 肥宅學游泳會比較快嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">mysterydream</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%82%A5%E5%AE%85%E5%AD%B8%E6%B8%B8%E6%B3%B3%E6%9C%83%E6%AF%94%E8%BC%83%E5%BF%AB%E5%97%8E%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3
搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/30</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">93</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538323290.A.B6E.html">[公告] 十月置底閒聊聊天文</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%8D%81%E6%9C%88%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E8%81%8A%E5%A4%A9%E6%96%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/01</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">17</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538921259.A.576.html">[協尋] 107/10/05 13:50台中公正路英才路段車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">q521q522</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;107%2F10%2F05&#43;13%3A50%E5%8F%B0%E4%B8%AD%E5%85%AC%E6%AD%A3%E8%B7%AF%E8%8B%B1%E6%89%8D%E8%B7%AF%E6%AE%B5%E8%BB%8A%E7%A6%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aq521q522">搜尋看板內 q521q522 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/07</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">19</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539159328.A.3DA.html">[公告] =姆咪=八卦板主徵選報名開始=姆咪=</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jacklyl</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%3D%E5%A7%86%E5%92%AA%3D%E5%85%AB%E5%8D%A6%E6%9D%BF%E4%B8%BB%E5%BE%B5%E9%81%B8%E5%A0%B1%E5%90%8D%E9%96%8B%E5%A7%8B%3D%E5%A7%86%E5%92%AA%3D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajacklyl">搜尋看板內 jacklyl 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ### 2.2 Selenium

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/Apple/anaconda3/lib/python3.7/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /Users/Apple/anaconda3/lib/python3.7/site-packages (from selenium) (1.24.1)

# %%
from selenium import webdriver
URL='https://www.ptt.cc/bbs/Boy-Girl/index.html'
driver = webdriver.Chrome("./chromedriver")
driver.get(URI)
btn=driver.find_element_by_name('yes')
driver.save_screenshot('before_click.png')
btn.click()
driver.save_screenshot('after_click.png')
print(driver.page_source)
# Out:
# 2020-04-09 00:59:26 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:49760/session {"capabilities": {"firstMatch": [{}], "alwaysMatch": {"browserName": "chrome", "platformName": "any", "goog:chromeOptions": {"extensions": [], "args": []}}}, "desiredCapabilities": {"browserName": "chrome", "version": "", "platform": "ANY", "goog:chromeOptions": {"extensions": [], "args": []}}}
# 2020-04-09 00:59:26 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): 127.0.0.1:49760
# 2020-04-09 00:59:28 [urllib3.connectionpool] DEBUG: http://127.0.0.1:49760 "POST /session HTTP/1.1" 200 689
# 2020-04-09 00:59:28 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-04-09 00:59:28 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:49760/session/19f3c3cffcdd8b6ef56ba87f59185d3e/url {"url": "https://www.ptt.cc/bbs/Gossiping/"}
# 2020-04-09 00:59:29 [urllib3.connectionpool] DEBUG: http://127.0.0.1:49760 "POST /session/19f3c3cffcdd8b6ef56ba87f59185d3e/url HTTP/1.1" 200 14
# 2020-04-09 00:59:29 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2020-04-09 00:59:29 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:49760/session/19f3c3cffcdd8b6ef56ba87f59185d3e/elements {"using": "xpath", "value": "//a[contains(text(), \"\u4e0a\u9801\")]"}
# 2020-04-09 00:59:29 [urllib3.connectionpool] DEBUG: http://127.0.0.1:49760 "POST /session/19f3c3cffcdd8b6ef56ba87f59185d3e/elements HTTP/1.1" 200 12
# 2020-04-09 00:59:29 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-3fec7c55189b> in <module>
#       4 driver.get(URI)
#       5 #btn=driver.find_element_by_name('yes')
# ----> 6 link = driver.find_elements_by_xpath('//a[contains(text(), "上頁")]')[0]
#       7 driver.save_screenshot('before_click.png')
#       8 btn.click()
#
# IndexError: list index out of range
